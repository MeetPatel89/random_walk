# %%
import numpy as np
import matplotlib.pyplot as plt
import random_dice_walk as rdw

# %%
# simulate 10 random walks (100 steps/dice rolls)
all_walks = []
for i in np.arange(10):
    all_walks.append(rdw.random_dice_walk_func(100))
all_walks_np = np.array(all_walks)

# %%
all_walks_np
# Out:
# array([[ 0,  1,  0, ..., 74, 75, 76],
#        [ 0,  1,  2, ..., 53, 54, 58],
#        [ 0,  1,  2, ..., 47, 48, 49],
#        ...,
#        [ 0,  1,  0, ..., 93, 97, 98],
#        [ 0,  1,  2, ..., 70, 71, 70],
#        [ 0,  1,  2, ..., 85, 86, 85]])

# %%
all_walks_np.shape
# Out:
# (10, 101)

# %%
# plotting the first random walk
plt.plot(all_walks_np[0])
plt.show()

# %%
# plotting all random walks
plt.plot(all_walks)
plt.show()

# %%
all_walks_np_t = all_walks_np.transpose()

# %%
# plotting all random walks using transposed all_walks_np_t array
plt.plot(all_walks_np_t)
plt.show()

# %%
# Implement 100 random walks 10 times
all_walks_arr = rdw.all_walks(10, 100)

# %%
all_walks_arr
# Out:
# array([[ 0,  1,  2, ..., 65, 66, 71],
#        [ 0,  5,  6, ..., 72, 73, 74],
#        [ 0,  1,  7, ..., 91, 94, 95],
#        ...,
#        [ 0,  0,  1, ..., 88, 89, 90],
#        [ 0,  4,  3, ..., 47, 48, 49],
#        [ 0,  0,  1, ..., 43, 44, 45]])

# %%
all_walks_transposed = all_walks_arr.transpose()

# %%
plt.plot(all_walks_transposed)
plt.show()
